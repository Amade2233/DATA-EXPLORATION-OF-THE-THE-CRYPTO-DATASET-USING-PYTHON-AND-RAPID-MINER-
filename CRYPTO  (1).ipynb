# %%
# NAME : ABUSOMWAN AMADEVBORHO
# ASSIGNMENT: PROGRAMMING FOR DATA ANALYTICS PROJECT 1
# K00266018

# %% [markdown]
# ---

# %%
# For Task1 we would be using the codes from week 2, 3, 4 and 5 which was taught in class 
# this include
# (A) LIST
#(B) SET
#(C) TUPLES
#(D) DICTIONARY
#(F) FUNCTIONS
#(G) STRING
#(H) STRING METHOD
#(I) BREAK AND CONTINUE STATEMENT 
#(J) ELSE
#(K) IF-ELSE
#(L) LOOP

# %% [markdown]
# ---

# %%
import csv

# %%
c_reader = csv.reader(open("C:\\Users\\Lenovo\\Desktop\\CRYPTO DATASET\\crypto-markets.csv", "r"), delimiter=",")

# %%
Crypto= list(zip(*c_reader))

# %% [markdown]
# ---

# %%
#Source of Dataset
#The dataset “crypto-markets.csv” was used in this project. The was accessed using the 
#url: https://www.kaggle.com/jessevent/all-crypto-currencies from Kaggle dataset website at www.kagle.com.

#This is a large time series csv file with 13 column and 942,297 rows. The dataset consists of various attributes, 
#and we would be focusing more on the “markets”, “open”, “close”, “low”, “high”, “spread”, “rank”, “close-ratio” etc which
#we would be exploring during this project.
#This is a time series dataset ranging from 28-04-2013 to 21-02-2018 at various “date”

# %%
type(Crypto)
# Out:
# list

# %%
len(Crypto)
# Out:
# 11

# %%
Crypto[0][0:9]
# Out:
# ('slug',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin')

# %% [markdown]
# ---

# %%
#(A) LIST

# %%
list1 = Crypto[0][0:]

# %%
list1
# Out:
# ('slug',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
#  'bitcoin',
# ...

# %%
list2 = Crypto[1][0:9]

# %%
list2
# Out:
# ('symbol', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC')

# %%
list3 = Crypto[4][0:900000:100000]

# %%
list3
# Out:
# ('ranknow', '169', '383', '628', '874', '1183', '1342', '1475', '1633')

# %%
list4 = Crypto[5][ : :200000]

# %%
list4
# Out:
# ('open', '0.024983', '0.025315', '0.013539', '0.000778')

# %%
list5 = Crypto[6][0:9]

# %%
list5
# Out:
# ('high',
#  '135.98',
#  '147.49',
#  '146.93',
#  '139.89',
#  '125.6',
#  '108.13',
#  '115',
#  '118.8')

# %%
list6 =  Crypto[7][-9:-1]

# %%
list6
# Out:
# ('22557.7',
#  '21814.8',
#  '21203.9',
#  '19240.1',
#  '17607.5',
#  '19292.9',
#  '19888.1',
#  '21457.95')

# %%
list7 =  Crypto[8][1:9]

# %%
list7
# Out:
# ('134.21', '144.54', '139', '116.99', '105.21', '97.75', '112.5', '115.91')

# %%
len(list7)
# Out:
# 8

# %%
max(list7)
# Out:
# '97.75'

# %%
min(list7)
# Out:
# '105.21'

# %%
# the market cap for BTC
Crypto[10][:9]
# Out:
# ('market',
#  '1488566728',
#  '1603768865',
#  '1542813125',
#  '1298954594',
#  '1168517495',
#  '1085995169',
#  '1250316563',
#  '1288693176')

# %%
BTCMARKET = Crypto[10][1:10]

# %%
type(BTCMARKET)
# Out:
# tuple

# %%
BTCMARKET = list(map(int, BTCMARKET))

# %%
BTCMARKET.sort()

# %%
print(BTCMARKET)
# Out:
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]

# %%
sum(BTCMARKET)
# Out:
# 11976648775

# %% [markdown]
# ---

# %%
#(B) SETS

# %%
BTCVolume = set(Crypto[9][244:251])

# %%
BTCVolume
# Out:
# {'19011300',
#  '20707700',
#  '20897300',
#  '22489400',
#  '32505800',
#  '38489500',
#  '46862700'}

# %%
print(BTCVolume)
# Out:
# {'46862700', '19011300', '32505800', '38489500', '20707700', '20897300', '22489400'}

# %%
type(BTCVolume)
# Out:
# set

# %%
BTCVolume = set(map(int, BTCVolume))

# %%
BTCVolume
# Out:
# {19011300, 20707700, 20897300, 22489400, 32505800, 38489500, 46862700}

# %%
max(BTCVolume)
# Out:
# 46862700

# %%
min(BTCVolume)
# Out:
# 19011300

# %%
sum(BTCVolume)
# Out:
# 200963700

# %%
BTCVolume
# Out:
# {19011300, 20707700, 20897300, 22489400, 32505800, 38489500, 46862700}

# %%
BTCVolume.add(200)

# %%
BTCVolume
# Out:
# {200, 19011300, 20707700, 20897300, 22489400, 32505800, 38489500, 46862700}

# %%
BTCVolume.remove(200)

# %%
BTCVolume
# Out:
# {19011300, 20707700, 20897300, 22489400, 32505800, 38489500, 46862700}

# %%
BTCVolume.add("high,demand,of,crytocurrency")

# %%
BTCVolume.remove("high,demand,of,crytocurrency")

# %% [markdown]
# ---

# %%
#(c) Tuples

# %%
list2 = Crypto[1][0:9]

# %%
list2
# Out:
# ('symbol', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC')

# %%
type(list2)
# Out:
# tuple

# %%
OPENMARKET = list4

# %%
OPENMARKET
# Out:
# ('open', '0.024983', '0.025315', '0.013539', '0.000778')

# %%
type(OPENMARKET)
# Out:
# tuple

# %% [markdown]
# ---

# %%
#(D) DICTIONARY

# %%
BTCVolume
# Out:
# {19011300, 20707700, 20897300, 22489400, 32505800, 38489500, 46862700}

# %%
dict = {"key1":"19011300", "key2": "20707700", "key3":"20897300", "key4": "22489400", "key5":"32505800", 
        "key6":"37810100", "key7":"38005000","key8":"38489500","key9":"46862700","key10":"72898496"}

# %%
dict["key2"]
# Out:
# '20707700'

# %%
dict1 = {"key1":19011300, "key2": 20707700, "key3":20897300, "key4": 22489400, "key5":32505800,
         "key6":37810100, "key7":38005000,"key8":38489500,"key9":46862700,"key10":72898496}

# %%
dict1["key3"]
# Out:
# 20897300

# %%
dict1["key7"]
# Out:
# 38005000

# %%
len(dict1)
# Out:
# 10

# %% [markdown]
# ---

# %%
#(F) FUNCTION

# %%
average = int(sum(BTCMARKET)+ max(BTCMARKET)+ min(BTCMARKET))/3

# %%
average
# Out:
# 4888804269.666667

# %%
import datetime

# %%
print('Welcome to online trading')
print('The average of the summary statistics Is:')
print(average)
print("Today is", datetime.datetime.now())
# Out:
# Welcome to online trading
# The average of the summary statistics Is:
# 4888804269.666667
# Today is 2021-12-02 23:05:47.909642

# %% [markdown]
# ---

# %%
#STRING METHOD

# %%
Crypto[5][0:8]
# Out:
# ('open', '135.3', '134.44', '144', '139', '116.38', '106.25', '98.1')

# %%
str= " ".join(Crypto[5][0:8])

# %%
str
# Out:
# 'open 135.3 134.44 144 139 116.38 106.25 98.1'

# %%
type(str)
# Out:
# str

# %%
str.isalnum()
# Out:
# False

# %%
str.isdecimal()
# Out:
# False

# %%
str.isdigit()
# Out:
# False

# %%
#Converting str

# %%
str.upper()
# Out:
# 'OPEN 135.3 134.44 144 139 116.38 106.25 98.1'

# %%
str.capitalize()
# Out:
# 'Open 135.3 134.44 144 139 116.38 106.25 98.1'

# %%
#Formating String

# %%
str.center(60)
# Out:
# '        open 135.3 134.44 144 139 116.38 106.25 98.1        '

# %%
str.ljust(50)
# Out:
# 'open 135.3 134.44 144 139 116.38 106.25 98.1      '

# %%
str.rjust(100)
# Out:
# '                                                        open 135.3 134.44 144 139 116.38 106.25 98.1'

# %% [markdown]
# ---

# %%
#(J)ELSE
#(K)IF-ELSE
#Loop

# %%
sum(BTCMARKET)/1000000
# Out:
# 11976.648775

# %%
max(BTCMARKET)/1000000
# Out:
# 1603.768865

# %%
min(BTCMARKET)/1000000
# Out:
# 1085.995169

# %%
BTC = int(input("ENTER BTC VALUE = "))
if BTC >= 9438.932539:
    print("Bull market: ")
    print("keep trading")
elif BTC >= 1603.768865 < 9438.932539:
    print("Bull market: Above maximum value")
    print( " Trade now")
elif BTC >= 1085.995169 < 1603.768865:
    print ( "Beer Market: Below minimum value")
    print ("Dont Trade")
else: 
    print("No trading")
print("Today is", datetime.datetime.now())
# Out:
# ENTER BTC VALUE = 1000000000000
# Bull market:
# keep trading
# Today is 2021-12-02 23:06:49.237034

# %%
Password = input("Enter Trading Password = ")

if Password == "Amade1991":
    print("Successful")
    print("Welcome to online Cryptocurrency Trading")
else:
    print("Invalid Password")
# Out:
# Enter Trading Password = 10000000000000000
# Invalid Password

# %%
BTCMAX = int(input("Enter maximum amount of bitcoin purchase: "))
BTCMIN = int(input("Enter minimum amount of bitcoin purcahse: "))

if BTCMAX >= 1603.768865:
    if BTCMIN >= 1085.995169:
        print("Bullish: Market trends favourable to invest")
    else:
        print("Bearish: Market trends not favourable to invest now")
else:
    print("No Trade")
# Out:
# Enter maximum amount of bitcoin purchase: 10000000000000000000
# Enter minimum amount of bitcoin purcahse: 10000000000000000
# Bullish: Market trends favourable to invest

# %%
BTCMARKET
# Out:
# [1085995169,
#  1168517495,
#  1249023060,
#  1250316563,
#  1288693176,
#  1298954594,
#  1488566728,
#  1542813125,
#  1603768865]

# %%
BTCMARKET.pop()
# Out:
# 1603768865

# %%
BTCMARKET.sort()

# %%
BTCMARKET
# Out:
# [1085995169,
#  1168517495,
#  1249023060,
#  1250316563,
#  1288693176,
#  1298954594,
#  1488566728,
#  1542813125]

# %%
#Loops

# %%
counter = 0
while counter < 5:
    counter = counter + 1
    print("Welcome to Online Crytocurrrency Trading")
    print("This week BTCVolume AND BTCMARKET Monday to Sunday")
    print(BTCVolume)
    print(BTCMARKET)
# Out:
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# ...

# %%
import time
start = time.time()
for i in range(5):
    print("BTCMARKET: ", i)
duration = time.time() - start    
print(duration)
# Out:
# BTCMARKET:  0
# BTCMARKET:  1
# BTCMARKET:  2
# BTCMARKET:  3
# BTCMARKET:  4
# 0.0009996891021728516

# %%
#Dispersion between time

# %%
import time
start = time.time()

type(Crypto)
len(Crypto)
Crypto[0][0:]
list1 = Crypto[0][0:]
list2 = Crypto[1][0:]
list3 = Crypto[4][0:900000:100000]
list4 = Crypto[5][ : :200000]
list5 = Crypto[6][0:]
list6 =  Crypto[7][-9:-1]
list7 =  Crypto[8][1:9]
len(list7)
max(list7)
min(list7)
Crypto[10][:9]
BTCMARKET = Crypto[10][1:10]
type(BTCMARKET)
BTCMARKET = list(map(int, BTCMARKET))
BTCMARKET.sort()
print(BTCMARKET)
sum(BTCMARKET)
BTCVolume = set(Crypto[9][244:251])
BTCVolume
print(BTCVolume)
type(BTCVolume)
BTCVolume = set(map(int, BTCVolume))
max(BTCVolume)
min(BTCVolume)
sum(BTCVolume)

average = int(sum(BTCMARKET)+ max(BTCMARKET)+ min(BTCMARKET))/3

BTC = int(input("ENTER BTC VALUE = "))
if BTC >= 9438.932539:
    print("Bull market: ")
    print("keep trading")
elif BTC >= 1603.768865 < 9438.932539:
    print("Bull market: Above maximum value")
    print( " Trade now")
elif BTC >= 1085.995169 < 1603.768865:
    print ( "Beer Market: Below minimum value")
    print ("Dont Trade")
else: 
    print("No trading")
print("Today is", datetime.datetime.now()) 

counter = 0
while counter < 5:
    counter = counter + 1
    print("Welcome to Online Crytocurrrency Trading")
    print("This week BTCVolume AND BTCMARKET Monday to Sunday")
    print(BTCVolume)
    print(BTCMARKET)
    
BTCMAX = int(input("Enter maximum amount of bitcoin purchase: "))
BTCMIN = int(input("Enter minimum amount of bitcoin purcahse: "))

if BTCMAX >= 1603.768865:
    if BTCMIN >= 1085.995169:
        print("Bullish: Market trends favourable to invest")
    else:
        print("Bearish: Market trends not favourable to invest now")
else:
    print("No Trade")    

Password = input("Enter Trading Password = ")

if Password == "Amade1991":
    print("Successful")
    print("Welcome to online Cryptocurrency Trading")
else:
    print("Invalid Password")
    
duration1 = time.time() - start  
print(duration1)
# Out:
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# {'46862700', '19011300', '32505800', '38489500', '20707700', '20897300', '22489400'}
# ENTER BTC VALUE = 100000000000000000
# Bull market:
# keep trading
# Today is 2021-12-02 23:07:41.105770
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# ...

# %%
print(duration1)
# Out:
# 28.39375615119934

# %% [markdown]
# ---

# %%
import csv
c_reader = csv.reader(open("C:\\Users\\Lenovo\\Desktop\\CRYPTO DATASET\\crypto-markets1.csv", "r"), delimiter=",")
Crypto= list(zip(*c_reader))

import datetime


import time
start = time.time()

type(Crypto)
len(Crypto)
Crypto[0][0:]
list1 = Crypto[0][0:]
list2 = Crypto[1][0:]
list3 = Crypto[4][0:900000:100000]
list4 = Crypto[5][ : :200000]
list5 = Crypto[6][0:]
list6 =  Crypto[7][-9:-1]
list7 =  Crypto[8][1:9]
len(list7)
max(list7)
min(list7)
Crypto[10][:9]
BTCMARKET = Crypto[10][1:10]
type(BTCMARKET)
BTCMARKET = list(map(int, BTCMARKET))
BTCMARKET.sort()
print(BTCMARKET)
sum(BTCMARKET)
BTCVolume = set(Crypto[9][244:251])
BTCVolume
print(BTCVolume)
type(BTCVolume)
BTCVolume = set(map(int, BTCVolume))
max(BTCVolume)
min(BTCVolume)
sum(BTCVolume)

average = int(sum(BTCMARKET)+ max(BTCMARKET)+ min(BTCMARKET))/3

BTC = int(input("ENTER BTC VALUE = "))
if BTC >= 9438.932539:
    print("Bull market: ")
    print("keep trading")
elif BTC >= 1603.768865 < 9438.932539:
    print("Bull market: Above maximum value")
    print( " Trade now")
elif BTC >= 1085.995169 < 1603.768865:
    print ( "Beer Market: Below minimum value")
    print ("Dont Trade")
else: 
    print("No trading")
print("Today is", datetime.datetime.now()) 

counter = 0
while counter < 5:
    counter = counter + 1
    print("Welcome to Online Crytocurrrency Trading")
    print("This week BTCVolume AND BTCMARKET Monday to Sunday")
    print(BTCVolume)
    print(BTCMARKET)
    
BTCMAX = int(input("Enter maximum amount of bitcoin purchase: "))
BTCMIN = int(input("Enter minimum amount of bitcoin purcahse: "))

if BTCMAX >= 1603.768865:
    if BTCMIN >= 1085.995169:
        print("Bullish: Market trends favourable to invest")
    else:
        print("Bearish: Market trends not favourable to invest now")
else:
    print("No Trade")    

Password = input("Enter Trading Password = ")

if Password == "Amade1991":
    print("Successful")
    print("Welcome to online Cryptocurrency Trading")
else:
    print("Invalid Password")
  
duration2 = time.time() - start 

print(duration2)
# Out:
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# {'46862700', '19011300', '32505800', '38489500', '20707700', '20897300', '22489400'}
# ENTER BTC VALUE = 1000000000000000000
# Bull market:
# keep trading
# Today is 2021-12-02 23:10:17.081572
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# ...

# %%
print(duration2)
# Out:
# 17.320692777633667

# %% [markdown]
# ---

# %%
import csv
c_reader = csv.reader(open("C:\\Users\\Lenovo\\Desktop\\CRYPTO DATASET\\crypto-marketsX2.csv", "r"), delimiter=",")
Crypto= list(zip(*c_reader))

import datetime

import time


start = time.time()

type(Crypto)
len(Crypto)
Crypto[0][0:]
list1 = Crypto[0][0:]
list2 = Crypto[1][0:]
list3 = Crypto[4][0:900000:100000]
list4 = Crypto[5][ : :200000]
list5 = Crypto[6][0:]
list6 =  Crypto[7][-9:-1]
list7 =  Crypto[8][1:9]
len(list7)
max(list7)
min(list7)
Crypto[10][:9]
BTCMARKET = Crypto[10][1:10]
type(BTCMARKET)
BTCMARKET = list(map(int, BTCMARKET))
BTCMARKET.sort()
print(BTCMARKET)
sum(BTCMARKET)
BTCVolume = set(Crypto[9][244:251])
BTCVolume
print(BTCVolume)
type(BTCVolume)
BTCVolume = set(map(int, BTCVolume))
max(BTCVolume)
min(BTCVolume)
sum(BTCVolume)

average = int(sum(BTCMARKET)+ max(BTCMARKET)+ min(BTCMARKET))/3

BTC = int(input("ENTER BTC VALUE = "))
if BTC >= 9438.932539:
    print("Bull market: ")
    print("keep trading")
elif BTC >= 1603.768865 < 9438.932539:
    print("Bull market: Above maximum value")
    print( " Trade now")
elif BTC >= 1085.995169 < 1603.768865:
    print ( "Beer Market: Below minimum value")
    print ("Dont Trade")
else: 
    print("No trading")
print("Today is", datetime.datetime.now()) 

counter = 0
while counter < 5:
    counter = counter + 1
    print("Welcome to Online Crytocurrrency Trading")
    print("This week BTCVolume AND BTCMARKET Monday to Sunday")
    print(BTCVolume)
    print(BTCMARKET)
    
BTCMAX = int(input("Enter maximum amount of bitcoin purchase: "))
BTCMIN = int(input("Enter minimum amount of bitcoin purcahse: "))

if BTCMAX >= 1603.768865:
    if BTCMIN >= 1085.995169:
        print("Bullish: Market trends favourable to invest")
    else:
        print("Bearish: Market trends not favourable to invest now")
else:
    print("No Trade")    

Password = input("Enter Trading Password = ")

if Password == "Amade1991":
    print("Successful")
    print("Welcome to online Cryptocurrency Trading")
else:
    print("Invalid Password")
    
duration3= time.time() - start 
print(duration3)
# Out:
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# {'46862700', '19011300', '32505800', '38489500', '20707700', '20897300', '22489400'}
# ENTER BTC VALUE = 11111111111111111
# Bull market:
# keep trading
# Today is 2021-12-02 23:10:57.675620
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# ...

# %%
print(duration3)
# Out:
# 10.754018783569336

# %% [markdown]
# ---

# %%
import csv
c_reader = csv.reader(open("C:\\Users\\Lenovo\\Desktop\\CRYPTO DATASET\\crypto-markets3.csv", "r"), delimiter=",")
Crypto= list(zip(*c_reader))

import datetime

import time


start = time.time()

type(Crypto)
len(Crypto)
Crypto[0][0:]
list1 = Crypto[0][0:]
list2 = Crypto[1][0:]
list3 = Crypto[4][0:900000:100000]
list4 = Crypto[5][ : :200000]
list5 = Crypto[6][0:]
list6 =  Crypto[7][-9:-1]
list7 =  Crypto[8][1:9]
len(list7)
max(list7)
min(list7)
Crypto[10][:9]
BTCMARKET = Crypto[10][1:10]
type(BTCMARKET)
BTCMARKET = list(map(int, BTCMARKET))
BTCMARKET.sort()
print(BTCMARKET)
sum(BTCMARKET)
BTCVolume = set(Crypto[9][244:251])
BTCVolume
print(BTCVolume)
type(BTCVolume)
BTCVolume = set(map(int, BTCVolume))
max(BTCVolume)
min(BTCVolume)
sum(BTCVolume)

average = int(sum(BTCMARKET)+ max(BTCMARKET)+ min(BTCMARKET))/3

BTC = int(input("ENTER BTC VALUE = "))
if BTC >= 9438.932539:
    print("Bull market: ")
    print("keep trading")
elif BTC >= 1603.768865 < 9438.932539:
    print("Bull market: Above maximum value")
    print( " Trade now")
elif BTC >= 1085.995169 < 1603.768865:
    print ( "Beer Market: Below minimum value")
    print ("Dont Trade")
else: 
    print("No trading")
print("Today is", datetime.datetime.now()) 

counter = 0
while counter < 5:
    counter = counter + 1
    print("Welcome to Online Crytocurrrency Trading")
    print("This week BTCVolume AND BTCMARKET Monday to Sunday")
    print(BTCVolume)
    print(BTCMARKET)
    
BTCMAX = int(input("Enter maximum amount of bitcoin purchase: "))
BTCMIN = int(input("Enter minimum amount of bitcoin purcahse: "))

if BTCMAX >= 1603.768865:
    if BTCMIN >= 1085.995169:
        print("Bullish: Market trends favourable to invest")
    else:
        print("Bearish: Market trends not favourable to invest now")
else:
    print("No Trade")    

Password = input("Enter Trading Password = ")

if Password == "Amade1991":
    print("Successful")
    print("Welcome to online Cryptocurrency Trading")
else:
    print("Invalid Password")
    
duration4= time.time() - start 
print(duration4)
# Out:
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# {'46862700', '19011300', '32505800', '38489500', '20707700', '20897300', '22489400'}
# ENTER BTC VALUE = 1111111111111111111
# Bull market:
# keep trading
# Today is 2021-12-02 23:11:30.427984
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# ...

# %%
print(duration4)
# Out:
# 14.167247533798218

# %% [markdown]
#
#
#
# ---

# %%
#TASK2

# %% [markdown]
# ---

# %%
import pandas as pd

# %%
Crypto = pd.read_csv(open("C:\\Users\\Lenovo\\Desktop\\CRYPTO DATASET\\crypto-markets.csv", "r"), delimiter=",")

# %%
len(Crypto)
# Out:
# 942297

# %%
Crypto
# Out:
#              slug symbol       name        date  ranknow      open      high  \
# 0         bitcoin    BTC    Bitcoin  2013-04-28      1.0    135.30    135.98
# 1         bitcoin    BTC    Bitcoin  2013-04-29      1.0    134.44    147.49
# 2         bitcoin    BTC    Bitcoin  2013-04-30      1.0    144.00    146.93
# 3         bitcoin    BTC    Bitcoin  2013-05-01      1.0    139.00    139.89
# 4         bitcoin    BTC    Bitcoin  2013-05-02      1.0    116.38    125.60
# ...           ...    ...        ...         ...      ...       ...       ...
# 942292  project-x  NANOX  Project-X  2018-11-26   1727.0  22424.60  23049.30
# 942293  project-x  NANOX  Project-X  2018-11-27   1727.0  20711.90  23742.10
# 942294  project-x  NANOX  Project-X  2018-11-28   1727.0  23320.90  25235.10
# 942295  project-x  NANOX  Project-X  2018-11-29   1727.0  24543.53  24582.47
# 942296  project-x  NANOX  Project-X  2018-11-30   1727.0  22872.09  23086.98
#
# ...

# %%
Crypto.describe()
# Out:
#              ranknow          open          high           low         close  \
# count  942297.000000  9.422970e+05  9.422970e+05  9.422970e+05  9.422970e+05
# mean     1000.170278  3.483522e+02  4.085930e+02  2.971928e+02  3.648381e+02
# std       587.575758  1.318436e+04  1.616386e+04  1.096732e+04  2.241307e+04
# min         0.030881  2.500000e-09  3.200000e-09  2.500000e-10  2.000000e-10
# 25%       465.000000  2.321000e-03  2.628000e-03  2.044000e-03  2.314000e-03
# 50%      1072.000000  2.398300e-02  2.680200e-02  2.143700e-02  2.389200e-02
# 75%      1484.000000  2.268600e-01  2.508940e-01  2.043920e-01  2.259350e-01
# max      2072.000000  2.298390e+06  2.926100e+06  2.030590e+06  1.765524e+07
#
#              volume        market   close_ratio        spread
# count  9.422970e+05  9.422970e+05  942296.00000  9.422960e+05
# mean   8.720382e+06  1.725060e+08       0.45950  1.123401e+02
# std    1.839802e+08  3.575590e+09       0.32616  6.783717e+03
# ...

# %%
Crypto.describe().transpose()
# Out:
#                 count          mean           std           min           25%  \
# ranknow      942297.0  1.000170e+03  5.875758e+02  3.088100e-02    465.000000
# open         942297.0  3.483522e+02  1.318436e+04  2.500000e-09      0.002321
# high         942297.0  4.085930e+02  1.616386e+04  3.200000e-09      0.002628
# low          942297.0  2.971928e+02  1.096732e+04  2.500000e-10      0.002044
# close        942297.0  3.648381e+02  2.241307e+04  2.000000e-10      0.002314
# volume       942297.0  8.720382e+06  1.839802e+08  0.000000e+00    175.000000
# market       942297.0  1.725060e+08  3.575590e+09  0.000000e+00  29581.000000
# close_ratio  942296.0  4.594999e-01  3.261605e-01 -1.000000e+00      0.162900
# spread       942296.0  1.123401e+02  6.783717e+03  0.000000e+00      0.000000
#
#                        50%           75%           max
# ranknow        1072.000000  1.484000e+03  2.072000e+03
# open              0.023983  2.268600e-01  2.298390e+06
# ...

# %%
len(list7)
# Out:
# 8

# %%
max(list7)
# Out:
# '97.75'

# %%
min(list7)
# Out:
# '105.21'

# %%
max(BTCVolume)
# Out:
# 46862700

# %%
BTCVolume
# Out:
# {19011300, 20707700, 20897300, 22489400, 32505800, 38489500, 46862700}

# %%
min(BTCVolume)
# Out:
# 19011300

# %%
type(BTCMARKET)
# Out:
# list

# %%
sum(BTCMARKET)
# Out:
# 11976648775

# %%
average = int(sum(BTCMARKET)+ max(BTCMARKET)+ min(BTCMARKET))/3

# %%
average
# Out:
# 4888804269.666667

# %%
counter = 0
while counter < 5:
    counter = counter + 1
    print("Welcome to Online Crytocurrrency Trading")
    print("This week BTCVolume AND BTCMARKET Monday to Sunday")
    print(BTCVolume)
    print(BTCMARKET)
# Out:
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# ...

# %%
BTC = int(input("ENTER BTC VALUE = "))
if BTC >= 9438.932539:
    print("Bull market: ")
    print("keep trading")
elif BTC >= 1603.768865 < 9438.932539:
    print("Bull market: Above maximum value")
    print( " Trade now")
elif BTC >= 1085.995169 < 1603.768865:
    print ( "Beer Market: Below minimum value")
    print ("Dont Trade")
else: 
    print("No trading")
print("Today is", datetime.datetime.now())
# Out:
# ENTER BTC VALUE = 11111111111111111111
# Bull market:
# keep trading
# Today is 2021-12-02 23:12:14.244250

# %%
BTCMAX = int(input("Enter maximum amount of bitcoin purchase: "))
BTCMIN = int(input("Enter minimum amount of bitcoin purcahse: "))

if BTCMAX >= 1603.768865:
    if BTCMIN >= 1085.995169:
        print("Bullish: Market trends favourable to invest")
    else:
        print("Bearish: Market trends not favourable to invest now")
else:
    print("No Trade")
# Out:
# Enter maximum amount of bitcoin purchase: 1111111111111111111
# Enter minimum amount of bitcoin purcahse: 11111111111111111111111
# Bullish: Market trends favourable to invest

# %%
Password = input("Enter Trading Password = ")

if Password == "Amade1991":
    print("Successful")
    print("Welcome to online Cryptocurrency Trading")
else:
    print("Invalid Password")
# Out:
# Enter Trading Password = 111111111111111111111
# Invalid Password

# %%
Crypto.head()
# Out:
#       slug symbol     name        date  ranknow    open    high     low  \
# 0  bitcoin    BTC  Bitcoin  2013-04-28      1.0  135.30  135.98  132.10
# 1  bitcoin    BTC  Bitcoin  2013-04-29      1.0  134.44  147.49  134.00
# 2  bitcoin    BTC  Bitcoin  2013-04-30      1.0  144.00  146.93  134.05
# 3  bitcoin    BTC  Bitcoin  2013-05-01      1.0  139.00  139.89  107.72
# 4  bitcoin    BTC  Bitcoin  2013-05-02      1.0  116.38  125.60   92.28
#
#     close  volume        market  close_ratio  spread
# 0  134.21     0.0  1.488567e+09       0.5438    3.88
# 1  144.54     0.0  1.603769e+09       0.7813   13.49
# 2  139.00     0.0  1.542813e+09       0.3843   12.88
# 3  116.99     0.0  1.298955e+09       0.2882   32.17
# 4  105.21     0.0  1.168517e+09       0.3881   33.32

# %%
Crypto.tail()
# Out:
#              slug symbol       name        date  ranknow      open      high  \
# 942292  project-x  NANOX  Project-X  2018-11-26   1727.0  22424.60  23049.30
# 942293  project-x  NANOX  Project-X  2018-11-27   1727.0  20711.90  23742.10
# 942294  project-x  NANOX  Project-X  2018-11-28   1727.0  23320.90  25235.10
# 942295  project-x  NANOX  Project-X  2018-11-29   1727.0  24543.53  24582.47
# 942296  project-x  NANOX  Project-X  2018-11-30   1727.0  22872.09  23086.98
#
#              low     close  volume  market  close_ratio   spread
# 942292  17607.50  20724.80   143.0  1622.0       0.5728  5441.80
# 942293  19292.90  23298.70   637.0  1823.0       0.9003  4449.20
# 942294  19888.10  24442.70    49.0  1913.0       0.8518  5347.00
# 942295  21457.95  22839.44   153.0  1788.0       0.4421  3124.52
# 942296  19040.91  21136.72   125.0  1654.0       0.5180  4046.07

# %%
Crypto[0:]
# Out:
#              slug symbol       name        date  ranknow      open      high  \
# 0         bitcoin    BTC    Bitcoin  2013-04-28      1.0    135.30    135.98
# 1         bitcoin    BTC    Bitcoin  2013-04-29      1.0    134.44    147.49
# 2         bitcoin    BTC    Bitcoin  2013-04-30      1.0    144.00    146.93
# 3         bitcoin    BTC    Bitcoin  2013-05-01      1.0    139.00    139.89
# 4         bitcoin    BTC    Bitcoin  2013-05-02      1.0    116.38    125.60
# ...           ...    ...        ...         ...      ...       ...       ...
# 942292  project-x  NANOX  Project-X  2018-11-26   1727.0  22424.60  23049.30
# 942293  project-x  NANOX  Project-X  2018-11-27   1727.0  20711.90  23742.10
# 942294  project-x  NANOX  Project-X  2018-11-28   1727.0  23320.90  25235.10
# 942295  project-x  NANOX  Project-X  2018-11-29   1727.0  24543.53  24582.47
# 942296  project-x  NANOX  Project-X  2018-11-30   1727.0  22872.09  23086.98
#
# ...

# %%
Crypto.columns
# Out:
# Index(['slug', 'symbol', 'name', 'date', 'ranknow', 'open', 'high', 'low',
#        'close', 'volume', 'market', 'close_ratio', 'spread'],
#       dtype='object')

# %%
Crypto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 942297 entries, 0 to 942296
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   slug         942297 non-null  object
#  1   symbol       942297 non-null  object
#  2   name         942297 non-null  object
#  3   date         942297 non-null  object
#  4   ranknow      942297 non-null  float64
#  5   open         942297 non-null  float64
#  6   high         942297 non-null  float64
#  7   low          942297 non-null  float64
#  8   close        942297 non-null  float64
#  9   volume       942297 non-null  float64
#  10  market       942297 non-null  float64
#  11  close_ratio  942296 non-null  float64
#  12  spread       942296 non-null  float64
# dtypes: float64(9), object(4)
# memory usage: 93.5+ MB

# %%
Crypto[0:100000:50000]
# Out:
#           slug symbol     name        date  ranknow        open        high  \
# 0      bitcoin    BTC  Bitcoin  2013-04-28      1.0  135.300000  135.980000
# 50000   revain      R   Revain  2018-06-02     63.0    0.475669    0.486522
#
#               low       close     volume        market  close_ratio  spread
# 0      132.100000  134.210000        0.0  1.488567e+09       0.5438    3.88
# 50000    0.462929    0.477588  1159420.0  8.904628e+07       0.6213    0.02

# %%
Crypto[["high","low"]][4:8]
# Out:
#      high     low
# 4  125.60   92.28
# 5  108.13   79.10
# 6  115.00   92.50
# 7  118.80  107.14

# %% [markdown]
# ---

# %%
import pandas as pd
Crypto = pd.read_csv(open("C:\\Users\\Lenovo\\Desktop\\CRYPTO DATASET\\crypto-markets.csv", "r"), delimiter=",")


import time
start = time.time()

len(Crypto)
Crypto
Crypto.describe()
Crypto.describe().transpose()
len(list7)
max(list7)
min(list7)
max(BTCVolume)
BTCVolume
min(BTCVolume)
sum(BTCMARKET)
average = int(sum(BTCMARKET)+ max(BTCMARKET)+ min(BTCMARKET))/3
average

Crypto.head()    
Crypto.tail()
Crypto[0:]
Crypto.columns
Crypto.info()
Crypto[0:100000:50000]
Crypto[["high","low"]][4:8]

counter = 0
while counter < 5:
    counter = counter + 1
    print("Welcome to Online Crytocurrrency Trading")
    print("This week BTCVolume AND BTCMARKET Monday to Sunday")
    print(BTCVolume)
    print(BTCMARKET)
    
BTC = int(input("ENTER BTC VALUE = "))
if BTC >= 9438.932539:
    print("Bull market: ")
    print("keep trading")
elif BTC >= 1603.768865 < 9438.932539:
    print("Bull market: Above maximum value")
    print( " Trade now")
elif BTC >= 1085.995169 < 1603.768865:
    print ( "Beer Market: Below minimum value")
    print ("Dont Trade")
else: 
    print("No trading")
print("Today is", datetime.datetime.now())     


BTCMAX = int(input("Enter maximum amount of bitcoin purchase: "))
BTCMIN = int(input("Enter minimum amount of bitcoin purcahse: "))

if BTCMAX >= 1603.768865:
    if BTCMIN >= 1085.995169:
        print("Bullish: Market trends favourable to invest")
    else:
        print("Bearish: Market trends not favourable to invest now")
else:
    print("No Trade")    

    
Password = input("Enter Trading Password = ")

if Password == "Amade1991":
    print("Successful")
    print("Welcome to online Cryptocurrency Trading")
else:
    print("Invalid Password")    
    
duration_pand1 = time.time() - start
print(duration_pand1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 942297 entries, 0 to 942296
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   slug         942297 non-null  object
#  1   symbol       942297 non-null  object
#  2   name         942297 non-null  object
#  3   date         942297 non-null  object
#  4   ranknow      942297 non-null  float64
#  5   open         942297 non-null  float64
#  6   high         942297 non-null  float64
#  7   low          942297 non-null  float64
#  8   close        942297 non-null  float64
#  9   volume       942297 non-null  float64
#  10  market       942297 non-null  float64
#  11  close_ratio  942296 non-null  float64
#  12  spread       942296 non-null  float64
# dtypes: float64(9), object(4)
# memory usage: 93.5+ MB
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# ...

# %%
print(duration_pand1)
# Out:
# 11.089498519897461

# %% [markdown]
# ---

# %%
import pandas as pd
Crypto = pd.read_csv(open("C:\\Users\\Lenovo\\Desktop\\CRYPTO DATASET\\crypto-markets1.csv", "r"), delimiter=",")



import time
start = time.time()

len(Crypto)
Crypto
Crypto.describe()
Crypto.describe().transpose()
len(list7)
max(list7)
min(list7)
max(BTCVolume)
BTCVolume
min(BTCVolume)
sum(BTCMARKET)
average = int(sum(BTCMARKET)+ max(BTCMARKET)+ min(BTCMARKET))/3
average

Crypto.head()    
Crypto.tail()
Crypto[0:]
Crypto.columns
Crypto.info()
Crypto[0:100000:50000]
Crypto[["high","low"]][4:8]

counter = 0
while counter < 5:
    counter = counter + 1
    print("Welcome to Online Crytocurrrency Trading")
    print("This week BTCVolume AND BTCMARKET Monday to Sunday")
    print(BTCVolume)
    print(BTCMARKET)
    
BTC = int(input("ENTER BTC VALUE = "))
if BTC >= 9438.932539:
    print("Bull market: ")
    print("keep trading")
elif BTC >= 1603.768865 < 9438.932539:
    print("Bull market: Above maximum value")
    print( " Trade now")
elif BTC >= 1085.995169 < 1603.768865:
    print ( "Beer Market: Below minimum value")
    print ("Dont Trade")
else: 
    print("No trading")
print("Today is", datetime.datetime.now())     


BTCMAX = int(input("Enter maximum amount of bitcoin purchase: "))
BTCMIN = int(input("Enter minimum amount of bitcoin purcahse: "))

if BTCMAX >= 1603.768865:
    if BTCMIN >= 1085.995169:
        print("Bullish: Market trends favourable to invest")
    else:
        print("Bearish: Market trends not favourable to invest now")
else:
    print("No Trade")    

    
Password = input("Enter Trading Password = ")

if Password == "Amade1991":
    print("Successful")
    print("Welcome to online Cryptocurrency Trading")
else:
    print("Invalid Password")    
    
duration_pand2 = time.time() - start
print(duration_pand2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997340 entries, 0 to 997339
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   slug         997340 non-null  object
#  1   symbol       997340 non-null  object
#  2   name         997340 non-null  object
#  3   date         997340 non-null  object
#  4   ranknow      997340 non-null  int64
#  5   open         997340 non-null  float64
#  6   high         997340 non-null  float64
#  7   low          997340 non-null  float64
#  8   close        997340 non-null  float64
#  9   volume       997340 non-null  float64
#  10  market       997340 non-null  float64
#  11  close_ratio  997340 non-null  float64
#  12  spread       997340 non-null  float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 98.9+ MB
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# ...

# %%
print(duration_pand2)
# Out:
# 10.4478120803833

# %% [markdown]
# ---

# %%
import pandas as pd
Crypto = pd.read_csv(open("C:\\Users\\Lenovo\\Desktop\\CRYPTO DATASET\\crypto-marketsX2.csv", "r"), delimiter=",")




import time
start = time.time()

len(Crypto)
Crypto
Crypto.describe()
Crypto.describe().transpose()
len(list7)
max(list7)
min(list7)
max(BTCVolume)
BTCVolume
min(BTCVolume)
sum(BTCMARKET)
average = int(sum(BTCMARKET)+ max(BTCMARKET)+ min(BTCMARKET))/3
average

Crypto.head()    
Crypto.tail()
Crypto[0:]
Crypto.columns
Crypto.info()
Crypto[0:100000:50000]
Crypto[["high","low"]][4:8]

counter = 0
while counter < 5:
    counter = counter + 1
    print("Welcome to Online Crytocurrrency Trading")
    print("This week BTCVolume AND BTCMARKET Monday to Sunday")
    print(BTCVolume)
    print(BTCMARKET)
    
BTC = int(input("ENTER BTC VALUE = "))
if BTC >= 9438.932539:
    print("Bull market: ")
    print("keep trading")
elif BTC >= 1603.768865 < 9438.932539:
    print("Bull market: Above maximum value")
    print( " Trade now")
elif BTC >= 1085.995169 < 1603.768865:
    print ( "Beer Market: Below minimum value")
    print ("Dont Trade")
else: 
    print("No trading")
print("Today is", datetime.datetime.now())     


BTCMAX = int(input("Enter maximum amount of bitcoin purchase: "))
BTCMIN = int(input("Enter minimum amount of bitcoin purcahse: "))

if BTCMAX >= 1603.768865:
    if BTCMIN >= 1085.995169:
        print("Bullish: Market trends favourable to invest")
    else:
        print("Bearish: Market trends not favourable to invest now")
else:
    print("No Trade")    

    
Password = input("Enter Trading Password = ")

if Password == "Amade1991":
    print("Successful")
    print("Welcome to online Cryptocurrency Trading")
else:
    print("Invalid Password")    
    
duration_pand3 = time.time() - start
print(duration_pand3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001084 entries, 0 to 1001083
# Data columns (total 13 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   slug         1001084 non-null  object
#  1   symbol       1001084 non-null  object
#  2   name         1001084 non-null  object
#  3   date         1001084 non-null  object
#  4   ranknow      1001084 non-null  int64
#  5   open         1001084 non-null  float64
#  6   high         1001084 non-null  float64
#  7   low          1001084 non-null  float64
#  8   close        1001084 non-null  float64
#  9   volume       1001084 non-null  float64
#  10  market       1001084 non-null  float64
#  11  close_ratio  1001084 non-null  float64
#  12  spread       1001084 non-null  float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 99.3+ MB
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# ...

# %%
print(duration_pand3)
# Out:
# 10.854735374450684

# %%
import pandas as pd
Crypto = pd.read_csv(open("C:\\Users\\Lenovo\\Desktop\\CRYPTO DATASET\\crypto-markets3.csv", "r"), delimiter=",")




import time
start = time.time()

len(Crypto)
Crypto
Crypto.describe()
Crypto.describe().transpose()
len(list7)
max(list7)
min(list7)
max(BTCVolume)
BTCVolume
min(BTCVolume)
sum(BTCMARKET)
average = int(sum(BTCMARKET)+ max(BTCMARKET)+ min(BTCMARKET))/3
average

Crypto.head()    
Crypto.tail()
Crypto[0:]
Crypto.columns
Crypto.info()
Crypto[0:100000:50000]
Crypto[["high","low"]][4:8]

counter = 0
while counter < 5:
    counter = counter + 1
    print("Welcome to Online Crytocurrrency Trading")
    print("This week BTCVolume AND BTCMARKET Monday to Sunday")
    print(BTCVolume)
    print(BTCMARKET)
    
BTC = int(input("ENTER BTC VALUE = "))
if BTC >= 9438.932539:
    print("Bull market: ")
    print("keep trading")
elif BTC >= 1603.768865 < 9438.932539:
    print("Bull market: Above maximum value")
    print( " Trade now")
elif BTC >= 1085.995169 < 1603.768865:
    print ( "Beer Market: Below minimum value")
    print ("Dont Trade")
else: 
    print("No trading")
print("Today is", datetime.datetime.now())     


BTCMAX = int(input("Enter maximum amount of bitcoin purchase: "))
BTCMIN = int(input("Enter minimum amount of bitcoin purcahse: "))

if BTCMAX >= 1603.768865:
    if BTCMIN >= 1085.995169:
        print("Bullish: Market trends favourable to invest")
    else:
        print("Bearish: Market trends not favourable to invest now")
else:
    print("No Trade")    

    
Password = input("Enter Trading Password = ")

if Password == "Amade1991":
    print("Successful")
    print("Welcome to online Cryptocurrency Trading")
else:
    print("Invalid Password")    
    
duration_pand4 = time.time() - start
print(duration_pand4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002144 entries, 0 to 1002143
# Data columns (total 13 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   slug         1002144 non-null  object
#  1   symbol       1002144 non-null  object
#  2   name         1002144 non-null  object
#  3   date         1002144 non-null  object
#  4   ranknow      1002144 non-null  int64
#  5   open         1002144 non-null  float64
#  6   high         1002144 non-null  float64
#  7   low          1002144 non-null  float64
#  8   close        1002144 non-null  float64
#  9   volume       1002144 non-null  float64
#  10  market       1002144 non-null  float64
#  11  close_ratio  1002144 non-null  float64
#  12  spread       1002144 non-null  float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 99.4+ MB
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# ...

# %%
print(duration_pand4)
# Out:
# 11.725078582763672

# %% [markdown]
# ---

# %%
from pandas import Series, DataFrame

# %%
import matplotlib.pyplot as plt

# %%
df_size = ["TF", "TFx2", "TFx3", "TFx4"]
python_Crypto= [duration1, duration2, duration3, duration4]
pandas_Crypto=[duration_pand1, duration_pand2, duration_pand3, duration_pand4]

# %%
df=pd.DataFrame(list(zip(python_Crypto,pandas_Crypto)), index= df_size, columns= ["python"+ " "+ "Crypto", "pandas_Crypto"])

# %%
df.plot.line(stacked=True)
plt.title("Disparity in time between python_Crypto and pandas_Crypto ")
# Out:
# Text(0.5, 1.0, 'Disparity in time between python_Crypto and pandas_Crypto ')

# %% [markdown]
# ---

# %%
#Task 3
#American Airlines Group DataSet

# %%
import csv

# %%
c_reader = csv.reader(open("C:\\Users\\Lenovo\\Desktop\\AAL.csv", "r"), delimiter=",")

# %%
AAL= list(zip(*c_reader))

# %%
AAL
# Out:
# [('Date',
#   '2005-09-27',
#   '2005-09-28',
#   '2005-09-29',
#   '2005-09-30',
#   '2005-10-03',
#   '2005-10-04',
#   '2005-10-05',
#   '2005-10-06',
#   '2005-10-07',
#   '2005-10-10',
#   '2005-10-11',
#   '2005-10-12',
#   '2005-10-13',
#   '2005-10-14',
#   '2005-10-17',
#   '2005-10-18',
#   '2005-10-19',
#   '2005-10-20',
#   '2005-10-21',
#   '2005-10-24',
#   '2005-10-25',
#   '2005-10-26',
#   '2005-10-27',
#   '2005-10-28',
#   '2005-10-31',
#   '2005-11-01',
#   '2005-11-02',
#   '2005-11-03',
#   '2005-11-04',
#   '2005-11-07',
#   '2005-11-08',
#   '2005-11-09',
#   '2005-11-10',
#   '2005-11-11',
#   '2005-11-14',
#   '2005-11-15',
#   '2005-11-16',
#   '2005-11-17',
#   '2005-11-18',
#   '2005-11-21',
#   '2005-11-22',
#   '2005-11-23',
#   '2005-11-25',
#   '2005-11-28',
#   '2005-11-29',
#   '2005-11-30',
#   '2005-12-01',
#   '2005-12-02',
#   '2005-12-05',
#   '2005-12-06',
#   '2005-12-07',
#   '2005-12-08',
#   '2005-12-09',
#   '2005-12-12',
# ...

# %%
type(AAL)
# Out:
# list

# %%
len(AAL)
# Out:
# 7

# %%
BTC = int(input("ENTER BTC VALUE = "))
if BTC >= 9438.932539:
    print("Bull market: ")
    print("keep trading")
elif BTC >= 1603.768865 < 9438.932539:
    print("Bull market: Above maximum value")
    print( " Trade now")
elif BTC >= 1085.995169 < 1603.768865:
    print ( "Beer Market: Below minimum value")
    print ("Dont Trade")
else: 
    print("No trading")
# Out:
# ENTER BTC VALUE = 11111111111111111
# Bull market:
# keep trading

# %%
counter = 0
while counter < 5:
    counter = counter + 1
    print("Welcome to Online Crytocurrrency Trading")
    print("This week BTCVolume AND BTCMARKET Monday to Sunday")
    print(BTCVolume)
    print(BTCMARKET)
# Out:
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# {19011300, 32505800, 46862700, 20707700, 20897300, 22489400, 38489500}
# [1085995169, 1168517495, 1249023060, 1250316563, 1288693176, 1298954594, 1488566728, 1542813125, 1603768865]
# Welcome to Online Crytocurrrency Trading
# This week BTCVolume AND BTCMARKET Monday to Sunday
# ...

# %%
BTCMAX = int(input("Enter maximum amount of bitcoin purchase: "))
BTCMIN = int(input("Enter minimum amount of bitcoin purcahse: "))

if BTCMAX >= 1603.768865:
    if BTCMIN >= 1085.995169:
        print("Bullish: Market trends favourable to invest")
    else:
        print("Bearish: Market trends not favourable to invest now")
else:
    print("No Trade")
# Out:
# Enter maximum amount of bitcoin purchase: 1111111111111111111
# Enter minimum amount of bitcoin purcahse: 222222222222222
# Bullish: Market trends favourable to invest

# %%
max(BTCVolume)
min(BTCVolume)
sum(BTCVolume)
# Out:
# 200963700

# %%
max(BTCVolume)
# Out:
# 46862700

# %%
average = int(sum(BTCMARKET)+ max(BTCMARKET)+ min(BTCMARKET))/3

# %%
average
# Out:
# 4888804269.666667
